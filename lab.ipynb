# %% [markdown]
# ## Configuration

# %%
"""Chunking strategy to divide text file into main topics."""
from KG_builder.extract.extract_triples import extract_triples
from KG_builder.utils.llm_utils import load_model

# %%
LLM_MODEL = "gemini-2.0-flash-lite"
EMBEDDING_MODEL = "Qwen/Qwen2.5-0.5B-Instruct"
THRESHOLE = 0.95
DATA = "./data"

# %%
import os

list_file = os.listdir(DATA)

# %% [markdown]
# ## Tạo bảng lưu

# %%
from KG_builder.models.db_engine import *

create_tables()
# Out:
# Đã tạo bảng thành công!

# %% [markdown]
# ## Load model

# %%
from KG_builder.embedding.load.free import QwenEmbedding

embed_model = QwenEmbedding(model_name=EMBEDDING_MODEL)
llm = load_model(LLM_MODEL)

# %%
embed_model.encode_sync(["Hello"]).shape
# Out:
# (1, 896)

# %% [markdown]
# ## Lấy triples

# %%
triples = []

# %%
for file_name in list_file:
    path = os.path.join(DATA, file_name)
    with open(path, "r", encoding="utf-8") as f:
        text = f.read()

    cleaned_text = clean_vn_text(text)

    section_boundaries = [
        ("THÔNG TIN CÁ NHÂN", "7. Quá trình công tác"),
        ("7. Quá trình công tác", "B. TỰ KHAI THEO")
    ]

    section_prompts = [
        (EXTRACT_TRIPLE_PERSONAL_INFO_PROMPT, EXTRACT_TRIPLE_PERSONAL_INFO_USER_PROMPT),
        (EXTRACT_TRIPLE_WORKING_INFO_PROMPT, EXTRACT_TRIPLE_WORKING_INFO_USER_PROMPT)
    ]

    main_subject = None

    for i, ((start_keyword, end_keyword), (system_instruction, context)) in enumerate(zip(section_boundaries, section_prompts)):
        section = extract_specific_sections(
            text=text,
            start_keyword=start_keyword,
            end_keyword=end_keyword
        )
        
        context_kwargs = {"context": section}
        if main_subject:
            context_kwargs["main_subject"] = main_subject

        messages = {
            "system_instruction": system_instruction.format(),
            "context": context.format(**context_kwargs)
        }
        
        response = extract_triples(
            messages=messages,
            llm=llm,
            response_format=response_format
        )
        
        for triple in response["triples"]:
            if not isinstance(triple, dict):
                continue
            add_triple_data(session=session, triple_data=triple)
        
        
        if i == 0:
            main_subject = response.get("triples")[0]["subject"]
# Out:
# {
#   "triples": [
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "has_birth_date",
#       "object": "24-07-1976",
#       "metadata": {
#         "source": "2. Ngày tháng năm sinh: 24/07/1976 ; Nam þ ; Nữ ; Quốc tịch: Việt Nam ;"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "gender",
#       "object": "Nam",
#       "metadata": {
#         "source": "2. Ngày tháng năm sinh: 24/07/1976 ; Nam þ ; Nữ ; Quốc tịch: Việt Nam ;"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "nationality",
#       "object": "Việt Nam",
#       "metadata": {
#         "source": "2. Ngày tháng năm sinh: 24/07/1976 ; Nam þ ; Nữ ; Quốc tịch: Việt Nam ;"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "ethnicity",
#       "object": "Kinh",
#       "metadata": {
#         "source": "Dân tộc: Kinh ; Tôn giáo: không"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "religion",
#       "object": "không",
#       "metadata": {
#         "source": "Dân tộc: Kinh ; Tôn giáo: không"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "party_member",
#       "object": "Đảng Cộng sản Việt Nam",
#       "metadata": {
#         "source": "3. Đảng viên Đảng Cộng sản Việt Nam: þ"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "was_born_in",
#       "object": "Vĩnh An, Vĩnh Lộc, Thanh Hóa",
#       "metadata": {
#         "source": "4. Quê quán (xã/phường, huyện/quận, tỉnh/thành phố): Vĩnh An, Vĩnh Lộc, Thanh Hóa"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "registered_residence",
#       "object": "số 39 Phố Hàng Buồm,Phường Hàng Buồm, Quận Hoàn Kiếm, thành phố Hà Nội",
#       "metadata": {
#         "source": "5. Nơi đăng ký hộ khẩu thường trú (số nhà, phố/thôn, xã/phường, huyện/quận, tỉnh/thành phố):"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "contact_address",
#       "object": "TS.Trần Quốc Hoà Bệnh viện Đại học Y Hà Nội, Số 1 Tôn Thất Tùng, Đống Đa, Hà Nội",
#       "metadata": {
#         "source": "6. Địa chỉ liên hệ (ghi rõ, đầy đủ để liên hệ được qua Bưu điện):"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "phone_number",
#       "object": "0983140525",
#       "metadata": {
#         "source": "6. Địa chỉ liên hệ (ghi rõ, đầy đủ để liên hệ được qua Bưu điện):\nĐiện thoại di động: 0983140525"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "email",
#       "object": "bshoadhy@gmail.com",
#       "metadata": {
#         "source": "6. Địa chỉ liên hệ (ghi rõ, đầy đủ để liên hệ được qua Bưu điện):\nĐiện thoại di động: 0983140525 E-mail: bshoadhy@gmail.com"
#       }
#     }
#   ]
# }
# {
#   "triples": [
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "worked_as",
#       "object": "Giảng viên Bộ môn Giải phẫu, Trường Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "1120-05-01T00:00:00Z",
#         "end_date": null,
#         "source": "Từ 11/2005 đến nay: Giảng viên Bộ môn Giải phẫu, Trường Đại học Y Hà Nội( Theo QĐ số 1554/QĐ - BYT ngày 27/4/2007."
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "worked_at",
#       "object": "Bệnh viện Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "0520-11-01T00:00:00Z",
#         "end_date": null,
#         "source": "Từ 05/2011 đến nay : Kiêm nhiệm công tác chuyên môn ngoại khoa tại Bệnh viện Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "worked_as",
#       "object": "Phó trưởng khoa khám bệnh, Bệnh viện Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "1220-12-01T00:00:00Z",
#         "end_date": "0720-07-01T00:00:00Z",
#         "source": "Từ 12/2017 đến 07/2020 Phó trưởng khoa khám bệnh, Bệnh viện Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "worked_as",
#       "object": "Phó trưởng đơn vị Ngoại Tiết niệu – Nam học",
#       "metadata": {
#         "start_date": "0420-04-01T00:00:00Z",
#         "end_date": "0220-02-01T00:00:00Z",
#         "source": "Từ 04/2019 đến 02/2021 Tạm giao nhiệm vụ Phó trưởng đơn vị Ngoại Tiết niệu – Nam học"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "worked_as",
#       "object": "Phó trưởng Phòng tổ chức hành chính, Bệnh viện Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "0820-08-01T00:00:00Z",
#         "end_date": "2520-01-01T00:00:00Z",
#         "source": "Từ 08/2020 đến 25/01/2022: Phó trưởng Phòng tổ chức hành chính, Bệnh viện Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "worked_as",
#       "object": "Phó trưởng khoa Ngoại Tiết niệu, Bệnh viện Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "0320-03-01T00:00:00Z",
#         "end_date": null,
#         "source": "Từ 03/2021 Đến nay: Phó trưởng khoa Ngoại Tiết niệu, Bệnh viện Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "worked_as",
#       "object": "Trưởng Phòng tổ chức hành chính, Bệnh viện Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "2620-01-01T00:00:00Z",
#         "end_date": null,
#         "source": "Từ 26/01/2022 đến nay: Trưởng Phòng tổ chức hành chính, Bệnh viện Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "current_position",
#       "object": "Trưởng phòng Tổ chức hành chính, phó trưởng khoa Ngoại Tiết niệu - Bệnh viện Đai học Y Hà Nội",
#       "metadata": {
#         "source": "Hiện nay: Trưởng phòng Tổ chức hành chính, phó trưởng khoa Ngoại Tiết niệu - Bệnh viện Đai học Y Hà Nội."
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "highest_position",
#       "object": "Phó trưởng khoa khám bệnh, Bệnh viện Đại học Y Hà Nội",
#       "metadata": {
#         "source": "Phó trưởng khoa khám bệnh, Bệnh viện Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "highest_position",
#       "object": "Phó trưởng Phòng tổ chức hành chính, Bệnh viện Đại học Y Hà Nội",
#       "metadata": {
#         "source": "Phó trưởng Phòng tổ chức hành chính, Bệnh viện Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "work_place",
#       "object": "Trường Đại học Y Hà Nội",
#       "metadata": {
#         "source": "Cơ quan công tác hiện nay: Trường Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "education",
#       "object": "Bác sĩ đa khoa",
#       "metadata": {
#         "start_date": "0720-07-25T00:00:00Z",
#         "end_date": null,
#         "source": "- Được cấp bằng ĐH ngày 25 tháng 07 năm 2005; số văn bằng: 0701529; ngành: Đa khoa,\nchuyên ngành: Bác sĩ đa khoa. Nơi cấp bằng ĐH (trường, nước): Trường Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "education",
#       "object": "Trường Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "0720-07-25T00:00:00Z",
#         "end_date": null,
#         "source": "- Được cấp bằng ĐH ngày 25 tháng 07 năm 2005; số văn bằng: 0701529; ngành: Đa khoa,\nchuyên ngành: Bác sĩ đa khoa. Nơi cấp bằng ĐH (trường, nước): Trường Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "education",
#       "object": "Giải phẫu người",
#       "metadata": {
#         "start_date": "0320-03-26T00:00:00Z",
#         "end_date": null,
#         "source": "- Được cấp bằng ThS ngày 26 tháng 03 năm 2009; số văn bằng: 046627; ngành: Y học ; chuyên\nngành: Giải phẫu người; Nơi cấp bằng ThS (trường, nước): Trường Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "education",
#       "object": "Trường Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "0320-03-26T00:00:00Z",
#         "end_date": null,
#         "source": "- Được cấp bằng ThS ngày 26 tháng 03 năm 2009; số văn bằng: 046627; ngành: Y học ; chuyên\nngành: Giải phẫu người; Nơi cấp bằng ThS (trường, nước): Trường Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "education",
#       "object": "Ngoại khoa",
#       "metadata": {
#         "start_date": "0520-05-29T00:00:00Z",
#         "end_date": null,
#         "source": "- Được cấp bằng TS ngày 29 tháng 05 năm 2019; số văn bằng: 10128; ngành: Y học; chuyên\nngành: Ngoại khoa; Nơi cấp bằng TS (trường, nước): Trường Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "education",
#       "object": "Trường Đại học Y Hà Nội",
#       "metadata": {
#         "start_date": "0520-05-29T00:00:00Z",
#         "end_date": null,
#         "source": "- Được cấp bằng TS ngày 29 tháng 05 năm 2019; số văn bằng: 10128; ngành: Y học; chuyên\nngành: Ngoại khoa; Nơi cấp bằng TS (trường, nước): Trường Đại học Y Hà Nội"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "research_direction",
#       "object": "Nghiên cứu Giải phẫu hệ tiết niệu, bạch huyết và ứng dụng trong lâm sàng lâm sàng.",
#       "metadata": {
#         "source": "- Nghiên cứu Giải phẫu hệ tiết niệu, bạch huyết và ứng dụng trong lâm sàng lâm sàng.\nHướng nghiên cứu thể hiện các bài báo:11,20,24,34,35,36,37,56,72 tại mẫu 1 mục 7.1a"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "research_direction",
#       "object": "Nghiên cứu can thiệp ít xâm lấn điều trị bệnh lý sỏi hệ tiết niệu.",
#       "metadata": {
#         "source": "- Nghiên cứu can thiệp ít xâm lấn điều trị bệnh lý sỏi hệ tiết niệu.Hướng nghiên cứu thể\nhiện các bài báo:1,6,12,13,15,16,21,22,23,29,30,31,33,38,39,40,41,42,44,46,48,52,54,70,71,79,80,82 tại mẫu 1 mục 7.1a"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "research_direction",
#       "object": "Nghiên cứu chẩn đoán và điều trị các bệnh lý khối U của hệ tiết niệu.",
#       "metadata": {
#         "source": "- Nghiên cứu chẩn đoán và điều trị các bệnh lý khối U của hệ tiết niệu. Hướng nghiên cứu\nthể hiện ở các bài báo:17,18,19,45,47,49,50,51,53,58,62,64,66,67,68,77,78 tại mẫu 1 mục 7.1a"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "research_direction",
#       "object": "Nghiên cứu chẩn đoán và điều trị bệnh lý cấp cứu, chấn thương hệ tiết niệu",
#       "metadata": {
#         "source": "- Nghiên cứu chẩn đoán và điều trị bệnh lý cấp cứu, chấn thương hệ tiết niệu, Hướng\nnghiên cứu thể hiện các bài báo:3,4,7,8,9,25,27,28,32,55,57,59,61,69,73,74,75,76,81 tại mẫu 1 mục 7.1a"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "research_direction",
#       "object": "Nghiên cứu điều trị các bệnh lý Nam học",
#       "metadata": {
#         "source": "- Nghiên cứu điều trị các bệnh lý Nam học. Hướng nghiên cứu thể hiện các bài báo:\n2,4,5,10,14,19,26,60,63 tại mẫu 1 mục 7.1a"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "supervised",
#       "object": "04 HVCH, 1 BSNT bảo vệ thành công luận văn ThS, BSNT",
#       "metadata": {
#         "source": "- Đã hướng dẫn (số lượng) 04 HVCH, 1 BSNT bảo vệ thành công luận văn ThS, BSNT (ứng\nviên chức danh GS không cần kê khai nội dung này);"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "research_project_completed",
#       "object": "05",
#       "metadata": {
#         "source": "- Đã hoàn thành đề tài NCKH từ cấp cơ sở trở lên: số lượng 05 cấp cơ sở"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "publications_count",
#       "object": "82",
#       "metadata": {
#         "source": "- Đã công bố 82 bài báo khoa học, trong đó 7 bài báo khoa học trên tạp chí quốc tế có uy tín;"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "international_publications_count",
#       "object": "7",
#       "metadata": {
#         "source": "- Đã công bố 82 bài báo khoa học, trong đó 7 bài báo khoa học trên tạp chí quốc tế có uy tín;"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "book_published",
#       "object": "02",
#       "metadata": {
#         "source": "- Số lượng sách đã xuất bản 02 trong đó 02 thuộc nhà xuất bản có uy tín;"
#       }
#     },
#     {
#       "subject": "TRẦN QUỐC HÒA",
#       "predicate": "award",
#       "object": "Bằng khen Tỉnh uỷ Bình Dương",
#       "metadata": {
#         "source": "15. Khen thưởng (các huân chương, huy chương, danh hiệu): Bằng khen Tỉnh uỷ Bình Dương"
#       }
#     }
#   ]
# }
# {
#   "triples": [
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "has_birth_date",
#       "object": "01/01/1964",
#       "metadata": {
#         "source": "2. Ngày tháng năm sinh: 01/01/1964; Nam: Nữ;"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "is_male",
#       "object": "Yes",
#       "metadata": {
#         "source": "2. Ngày tháng năm sinh: 01/01/1964; Nam: Nữ;"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "has_nationality",
#       "object": "Việt Nam",
#       "metadata": {
#         "source": "Quốc tịch: Việt Nam;"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "has_ethnicity",
#       "object": "Kinh",
#       "metadata": {
#         "source": "Dân tộc: Kinh; Tôn giáo: Không"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "has_religion",
#       "object": "Không",
#       "metadata": {
#         "source": "Dân tộc: Kinh; Tôn giáo: Không"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "is_a_member_of_the_communist_party_of_vietnam",
#       "object": "Yes",
#       "metadata": {
#         "source": "3. Đảng viên Đảng Cộng sản Việt Nam:"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "was_born_in",
#       "object": "Quảng Ngãi",
#       "metadata": {
#         "source": "4. Quê quán (xã/phường, huyện/quận, tỉnh/thành phố): Quảng Ngãi"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "has_registered_residence",
#       "object": "400 Lê Văn Sỹ Phường 14 Quận 3 Tp Hồ Chí Minh",
#       "metadata": {
#         "source": "5. Nơi đăng ký hộ khẩu thường trú (số nhà, phố/thôn, xã/phường, huyện/quận,\ntỉnh/thành phố): 400 Lê Văn Sỹ Phường 14 Quận 3 Tp Hồ Chí Minh."
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "has_contact_address",
#       "object": "Bệnh viện Chợ Rẫy,201B Nguyễn Chí Thanh Phường 12, Quận 5, Tp Hồ Chí Minh.",
#       "metadata": {
#         "source": "6. Địa chỉ liên hệ (ghi rõ, đầy đủ để liên hệ được qua Bưu điện): Bệnh viện Chợ Rẫy,\n201B Nguyễn Chí Thanh Phường 12, Quận 5, Tp Hồ Chí Minh."
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "has_phone_number",
#       "object": "0908011848",
#       "metadata": {
#         "source": "Điện thoại di động: 0908011848; E-mail: nghia2000@gmail.com"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "has_email",
#       "object": "nghia2000@gmail.com",
#       "metadata": {
#         "source": "Điện thoại di động: 0908011848; E-mail: nghia2000@gmail.com"
#       }
#     }
#   ]
# }
# {
#   "triples": [
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "worked_as",
#       "object": "Bác sĩ nội trú, khoa Tim Mạch bệnh viện Chợ Rẫy",
#       "metadata": {
#         "start_date": "1988-12-31T17:00:00-07:00",
#         "end_date": "1992-12-31T17:00:00-07:00",
#         "source": "- Từ năm: 1988 đến năm 1992: Bác sĩ nội trú, khoa Tim Mạch bệnh viện Chợ Rẫy"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "worked_as",
#       "object": "Bác sĩ điều trị, Bộ môn Nội - Khoa Tim Mạch BV Chợ Rẫy",
#       "metadata": {
#         "start_date": "1992-12-31T17:00:00-07:00",
#         "end_date": "1994-12-31T17:00:00-07:00",
#         "source": "- Từ năm: 1992 đến năm 1994: Bác sĩ điều trị, Bộ môn Nội - Khoa Tim Mạch BV\nChợ Rẫy"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "worked_as",
#       "object": "Bác sĩ phòng khám xuất cảnh, bệnh viện Chợ Rẫy",
#       "metadata": {
#         "start_date": "1995-12-31T17:00:00-07:00",
#         "end_date": "1997-12-31T17:00:00-07:00",
#         "source": "- Từ năm: 1995 đến năm 1997: Bác sĩ phòng khám xuất cảnh, bệnh viện Chợ Rẫy"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "worked_as",
#       "object": "Bác sĩ chuyên khoa Tim mạch, Tổ trưởng tổ chụp\nvà can thiệp động mạch vành, khoa Tim Mạch bệnh viện Chợ Rẫy X",
#       "metadata": {
#         "start_date": "1998-12-31T17:00:00-07:00",
#         "end_date": "2003-12-31T17:00:00-07:00",
#         "source": "- Từ năm: 1998 đến năm 2003: Bác sĩ chuyên khoa Tim mạch, Tổ trưởng tổ chụp\nvà can thiệp động mạch vành, khoa Tim Mạch bệnh viện Chợ Rẫy X"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "worked_as",
#       "object": "Phó trưởng khoa, Khoa Tim Mạch Can Thiệp BV Chợ\nRẫy",
#       "metadata": {
#         "start_date": "2004-12-31T17:00:00-07:00",
#         "end_date": "2015-12-31T17:00:00-07:00",
#         "source": "- Từ năm: 2004 đến năm 2015: Phó trưởng khoa, Khoa Tim Mạch Can Thiệp BV Chợ\nRẫy"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "worked_as",
#       "object": "Phó Giám đốc Trung tâm Tim Mạch kiêm Trưởng khoa\nTim Mạch Can Thiệp Bệnh viện Chợ Rẫy",
#       "metadata": {
#         "start_date": "6201-01-01T00:00:00-07:00",
#         "end_date": null,
#         "source": "- Từ tháng 6/2015 đến nay: Phó Giám đốc Trung tâm Tim Mạch kiêm Trưởng khoa\nTim Mạch Can Thiệp Bệnh viện Chợ Rẫy"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "position",
#       "object": "Phó Giám đốc Trung tâm Tim Mạch kiêm Trưởng khoa Tim\nMạch Can Thiệp bệnh viện Chợ Rẫy",
#       "metadata": {
#         "source": "- Chức vụ hiện nay: Phó Giám đốc Trung tâm Tim Mạch kiêm Trưởng khoa Tim\nMạch Can Thiệp bệnh viện Chợ Rẫy;"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "highest_position",
#       "object": "Phó Giám đốc Trung tâm Tim Mạch",
#       "metadata": {
#         "source": "- Chức vụ cao nhất đã qua: Phó Giám đốc Trung tâm Tim Mạch"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "workplace",
#       "object": "Bệnh viện Chợ Rẫy",
#       "metadata": {
#         "source": "- Cơ quan công tác hiện nay: Bệnh viện Chợ Rẫy"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "address",
#       "object": "201B Nguyễn Chí Thanh, Phường 12, Quận 5, Tp Hồ Chí Minh",
#       "metadata": {
#         "source": "- Địa chỉ cơ quan: 201B Nguyễn Chí Thanh, Phường 12, Quận 5, Tp Hồ Chí Minh"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "phone_number",
#       "object": "028 39557119",
#       "metadata": {
#         "source": "- Điện thoại cơ quan: 028 39557119"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "lectured_at",
#       "object": "Đại học Y Dược TPHCM",
#       "metadata": {
#         "source": "o Đại học Y Dược TPHCM o Khoa Y Đại học Quốc gia Tp Hồ Chí Minh o Trường đại học Y Khoa Phạm Ngọc Thạch"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "lectured_at",
#       "object": "Khoa Y Đại học Quốc gia Tp Hồ Chí Minh",
#       "metadata": {
#         "source": "o Đại học Y Dược TPHCM o Khoa Y Đại học Quốc gia Tp Hồ Chí Minh o Trường đại học Y Khoa Phạm Ngọc Thạch"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "lectured_at",
#       "object": "Trường đại học Y Khoa Phạm Ngọc Thạch",
#       "metadata": {
#         "source": "o Đại học Y Dược TPHCM o Khoa Y Đại học Quốc gia Tp Hồ Chí Minh o Trường đại học Y Khoa Phạm Ngọc Thạch"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "lectured_at",
#       "object": "Đại học Y Dược TPHCM",
#       "metadata": {
#         "source": "o Đại học Y Dược TPHCM;"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "lectured_at",
#       "object": "Khoa Y Đại học Quốc gia Tp Hồ Chí Minh",
#       "metadata": {
#         "source": "o Khoa Y Đại học Quốc gia Tp Hồ Chí Minh;"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "degree",
#       "object": "Đại học Y Dược tp Hồ Chí Minh – Việt Nam",
#       "metadata": {
#         "start_date": "2105-01-01T00:00:00-07:00",
#         "end_date": null,
#         "source": "- Được cấp bằng Đại học ngày 21 tháng 05 năm 1990; số văn bằng: A 62057; ngành: Y, chuyên ngành: Đa khoa hệ nội; Nơi cấp bằng Đại học: Đại học Y Dược tp Hồ Chí Minh – Việt Nam"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "degree",
#       "object": "Đại học Y Dược tp Hồ Chí Minh – Việt Nam",
#       "metadata": {
#         "start_date": "1105-01-01T00:00:00-07:00",
#         "end_date": null,
#         "source": "- Được cấp bằng Thạc sĩ ngày 11 tháng 05 năm 1998; số văn bằng: 7472; ngành: Y; chuyên ngành: Thạc sĩ Y học; Nơi cấp bằng Thạc sĩ: Đại học Y Dược tp Hồ Chí Minh – Việt Nam"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "degree",
#       "object": "Đại học Y Dược tp Hồ Chí Minh – Việt Nam",
#       "metadata": {
#         "start_date": "1806-01-01T00:00:00-07:00",
#         "end_date": null,
#         "source": "- Được cấp bằng Tiến sĩ ngày 18 tháng 06 năm 2012; số văn bằng: 000588; ngành: Y; chuyên ngành: Tiến sỹ Y học; Nơi cấp bằng Tiến sĩ: Đại học Y Dược tp Hồ Chí Minh – Việt Nam"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Trung tâm đào tạo và bồi dưỡng cán bộ Y tế TP",
#       "metadata": {
#         "start_date": "0110-01-01T00:00:00-07:00",
#         "end_date": "0701-01-01T00:00:00-07:00",
#         "source": "Siêu âm tim 2D và DOPPLER màu 01/10/1992 - 07/01/1993 Trung tâm đào tạo và bồi dưỡng cán bộ Y tế TP Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Trung tâm đào tạo và bồi dưỡng cán bộ Y tế TP",
#       "metadata": {
#         "start_date": "0806-01-01T00:00:00-07:00",
#         "end_date": "0906-01-01T00:00:00-07:00",
#         "source": "Siêu âm tim qua đường thực quản 08/0609/06/1998 Trung tâm đào tạo và bồi dưỡng cán bộ Y tế TP Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "CDC Hoa Kỳ",
#       "metadata": {
#         "start_date": "0906-01-01T00:00:00-07:00",
#         "end_date": null,
#         "source": "The medical examination of visa applicants Khám sức khỏe tổng quát cho người di dân 09/06/1995 CDC Hoa Kỳ Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Center Hospitalier Universitaire Vaudois (CHUV) Thụy Sĩ",
#       "metadata": {
#         "start_date": "0520-01-01T00:00:00-07:00",
#         "end_date": "0620-01-01T00:00:00-07:00",
#         "source": "Intravascular ultrasound and intracoronary pressure measurements Thông tim- đo áp lực và siêu âm nội mạch vành (IVUS). Siêu âm trong buồng tim (ICE) 05-06/ 2008 Center Hospitalier Universitaire Vaudois (CHUV) Thụy Sĩ Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Her Majesty Cardiac Center, Faculty of Medicine Siriraj Hospital Mahidol University – Thái Lan",
#       "metadata": {
#         "start_date": "2304-01-01T00:00:00-07:00",
#         "end_date": "2304-01-01T00:00:00-07:00",
#         "source": "Khoan cắt mảng xơ vữa và siêu âm nội mạch động mạch vành Rotational Atherectomy and IVUS Imaging 23/04/2017 Her Majesty Cardiac Center, Faculty of Medicine Siriraj Hospital Mahidol University – Thái Lan Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Heart center Righospitalet, Conpenhagen Denmark – Đan Mạch",
#       "metadata": {
#         "start_date": "2808-01-01T00:00:00-07:00",
#         "end_date": "1009-01-01T00:00:00-07:00",
#         "source": "TAVI training course Thay van động mạch chủ qua da 28/08- 10/09/2017 Heart center Righospitalet, Conpenhagen Denmark – Đan Mạch Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Teikyo University Hospital, Tokyo, Japan – Nhật",
#       "metadata": {
#         "start_date": "0904-01-01T00:00:00-07:00",
#         "end_date": "1104-01-01T00:00:00-07:00",
#         "source": "IVUS Fellowship Siêu âm nội mạch động mạch vành 09/04- 11/04/2018 Teikyo University Hospital, Tokyo, Japan – Nhật Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "SCAI (Hội Tim mạch Can thiệp Hoa Kỳ)",
#       "metadata": {
#         "start_date": "2020-12-31T17:00:00-07:00",
#         "end_date": null,
#         "source": "Fellowship of SCAI (FSCAI) Thực tập sinh khoa học - Hội Tim mạch Can thiệp Hoa Kỳ (The Society for Cardiovascular Angiography & Intervention-SCAI) 2020 SCAI (Hội Tim mạch Can thiệp Hoa Kỳ) Chứng nhận"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Đại học Y Dược Tp Hồ Chí Minh",
#       "metadata": {
#         "start_date": "1712-01-01T00:00:00-07:00",
#         "end_date": "0201-01-01T00:00:00-07:00",
#         "source": "Thống kê căn bản trong nghiên cứu y học 17/12/2003 - 02/01/2004 Đại học Y Dược Tp Hồ Chí Minh Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Viện Garvan (Úc)",
#       "metadata": {
#         "start_date": "1812-01-01T00:00:00-07:00",
#         "end_date": null,
#         "source": "Thiết kế nghiên cứu khoa học lâm sàng 18/12/2011 Viện Garvan (Úc) Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Đại học Quốc gia tp Hồ Chí Minh",
#       "metadata": {
#         "start_date": "1203-01-01T00:00:00-07:00",
#         "end_date": "1403-01-01T00:00:00-07:00",
#         "source": "Viết bài báo khoa học 12/3- 14/03/2012 Đại học Quốc gia tp Hồ Chí Minh Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Đại học Y Dược TP HCM",
#       "metadata": {
#         "start_date": "2910-01-01T00:00:00-07:00",
#         "end_date": null,
#         "source": "Sư phạm y học 29/10/1997 Đại học Y Dược TP HCM Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Đại học Y Dược TP HCM",
#       "metadata": {
#         "start_date": "1506-01-01T00:00:00-07:00",
#         "end_date": "2606-01-01T00:00:00-07:00",
#         "source": "Phương Pháp giảng dạy và lượng giá lâm sàng dựa trên năng lực 15/626/6/2020 Đại học Y Dược TP HCM Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Trường Đại học Tổng hợp TP HCM",
#       "metadata": {
#         "start_date": "2209-01-01T00:00:00-07:00",
#         "end_date": "2711-01-01T00:00:00-07:00",
#         "source": "Tin học 22/09/- 27/11/1993 Trường Đại học Tổng hợp TP HCM Chứng chỉ"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Trường Cán bộ TPHCM",
#       "metadata": {
#         "start_date": "2007-12-31T17:00:00-07:00",
#         "end_date": "2008-12-31T17:00:00-07:00",
#         "source": "Trung Cấp Chính trị 2007-2008 Trường Cán bộ TPHCM Bằng"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "training",
#       "object": "Trường Đại học Y tế công cộng",
#       "metadata": {
#         "start_date": "1308-01-01T00:00:00-07:00",
#         "end_date": "2409-01-01T00:00:00-07:00",
#         "source": "Khóa học bồi dưỡng theo tiêu chuẩn chức danh nghề nghiệp bác sĩ cao cấp (hạng 1) 13/824/09/2019 Trường Đại học Y tế công cộng Chứng nhận"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "registered_for_position",
#       "object": "Phó Giáo sư",
#       "metadata": {
#         "source": "10. Đăng ký xét đạt tiêu chuẩn chức danh Phó Giáo sư tại HĐGS cơ sở: Đại học Y\nDược TPHCM"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "registered_for_position",
#       "object": "Phó Giáo sư",
#       "metadata": {
#         "source": "11. Đăng ký xét đạt tiêu chuẩn chức danh Phó Giáo sư tại HĐGS ngành, liên ngành:\nY Khoa"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "supervised",
#       "object": "18 HVCH/CK2/BSNT",
#       "metadata": {
#         "source": "- Đã hướng dẫn 18 HVCH/CK2/BSNT và các học viên đã bảo vệ thành công luận\nvăn ThS/CK2 /BSNT;"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "completed_research",
#       "object": "14 đề tài",
#       "metadata": {
#         "source": "- Đã hoàn thành đề tài NCKH từ cấp cơ sở trở lên: gồm 14 đề tài; trong đó có 06\nđề tài cấp cơ sở, 02 đề tài cấp thành phố, 04 đề tài cấp bộ và 02 đề tài cấp nhà nước."
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "published_papers",
#       "object": "56 bài báo",
#       "metadata": {
#         "source": "- Đã công bố 56 bài báo khoa học, trong đó có 16 bài báo khoa học được đăng trên\ntạp chí quốc tế và là tác giả chính của 05 bài báo được đăng trên tạp chí quốc tế uy tín có trong hệ thống ISI, Scopus"
#       }
#     },
#     {
#       "subject": "NGUYỄN THƯỢNG NGHĨA",
#       "predicate": "published_books",
#       "object": "02 quyển",
#       "metadata": {
#         "source": "- Số lượng sách đã xuất bản 02 quyển thuộc nhà xuất bản Y học"
#       }
#     }
#   ]
# }
# {
#     "triples": [
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "has_birth_date",
#             "object": "18-11-1975",
#             "metadata": {
#                 "source": "2. Ngày tháng năm sinh: 18 - 11 - 1975; Nam \nf0fe; Nữ □; Quốc tịch: Việt Nam"
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "gender",
#             "object": "Nam",
#             "metadata": {
#                 "source": "2. Ngày tháng năm sinh: 18 - 11 - 1975; Nam \nf0fe; Nữ □; Quốc tịch: Việt Nam"
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "nationality",
#             "object": "Việt Nam",
#             "metadata": {
#                 "source": "2. Ngày tháng năm sinh: 18 - 11 - 1975; Nam \nf0fe; Nữ □; Quốc tịch: Việt Nam"
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "ethnicity",
#             "object": "Kinh",
#             "metadata": {
#                 "source": "Dân tộc: Kinh ; Tôn giáo: Không"
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "religion",
#             "object": "Không",
#             "metadata": {
#                 "source": "Dân tộc: Kinh ; Tôn giáo: Không"
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "party_member_of",
#             "object": "Đảng Cộng sản Việt Nam",
#             "metadata": {
#                 "source": "3. Đảng viên Đảng Cộng sản Việt Nam: \nf0fe"
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "was_born_in",
#             "object": "Xã Hưng Thành - Huyện\nHưng Nguyên - Tỉnh Nghệ An",
#             "metadata": {
#                 "source": "4. Quê quán: xã/phường, huyện/quận, tỉnh/thành phố: Xã Hưng Thành - Huyện\nHưng Nguyên - Tỉnh Nghệ An."
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "registered_residence",
#             "object": "Khối 15 - Phường Cửa Nam - Thành phố Vinh - Tỉnh Nghệ An",
#             "metadata": {
#                 "source": "5. Nơi đăng ký hộ khẩu thường trú (số nhà, phố, phường, quận, thành phố hoặc\nxã, huyện, tỉnh): Khối 15 - Phường Cửa Nam - Thành phố Vinh - Tỉnh Nghệ An."
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "contact_address",
#             "object": "Nguyễn Văn\nTuấn - Bộ môn Nội tổng hợp, Trường Đại học Y khoa Vinh, 161 - Nguyễn Phong Sắc - Phường Hưng Dũng - Thành phố Vinh - Tỉnh Nghệ An.",
#             "metadata": {
#                 "source": "6. Địa chỉ liên hệ (ghi rõ, đầy đủ để liên hệ được qua Bưu điện): Nguyễn Văn\nTuấn - Bộ môn Nội tổng hợp, Trường Đại học Y khoa Vinh, 161 - Nguyễn Phong Sắc - Phường Hưng Dũng - Thành phố Vinh - Tỉnh Nghệ An."
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "phone_number",
#             "object": "0983 767134",
#             "metadata": {
#                 "source": "Điện thoại di động: 0983 767134 ;"
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "email",
#             "object": "vantuan@vmu.edu.vn",
#             "metadata": {
#                 "source": "E-mail: vantuan@vmu.edu.vn hoặc tuanminh1975@gmail.com"
#             }
#         },
#         {
#             "subject": "NGUYỄN VĂN TUẤN",
#             "predicate": "email",
#             "object": "tuanminh1975@gmail.com",
#             "metadata": {
#                 "source": "E-mail: vantuan@vmu.edu.vn hoặc tuanminh1975@gmail.com"
#             }
#         }
#     ]
# }
# {
#   "triples": [
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "worked_as",
#       "object": "Giáo viên Bộ môn Nội, Trường Trung học Y tế Nghệ An",
#       "metadata": {
#         "start_date": "1120-01-01T00:00:00Z",
#         "end_date": "0820-01-01T00:00:00Z",
#         "source": "Từ tháng 11 năm 2000 đến tháng 8 năm 2003: Giáo viên Bộ môn Nội, Trường Trung học Y tế Nghệ An."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "worked_as",
#       "object": "Giảng viên Bộ môn Nội - Trường Cao đẳng Y tế Nghệ An",
#       "metadata": {
#         "start_date": "0920-01-01T00:00:00Z",
#         "end_date": "0820-01-01T00:00:00Z",
#         "source": "Từ tháng 9 năm 2003 đến tháng 8 năm 2011: Giảng viên Bộ môn Nội - Trường Cao đẳng Y tế Nghệ An."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "worked_as",
#       "object": "Giảng viên Bộ môn Nội, Trường Đại học Y khoa Vinh",
#       "metadata": {
#         "start_date": "0920-01-01T00:00:00Z",
#         "end_date": "1220-01-01T00:00:00Z",
#         "source": "Từ tháng 9 năm 2011 đến tháng 12 năm 2015: Giảng viên Bộ môn Nội, Trường Đại học Y khoa Vinh."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "worked_as",
#       "object": "Giảng viên, Trưởng Bộ môn Nội tổng hợp, Trường Đại học Y khoa Vinh",
#       "metadata": {
#         "start_date": "0120-01-01T00:00:00Z",
#         "end_date": "0820-01-01T00:00:00Z",
#         "source": "Từ tháng 01 năm 2016 đến tháng 8 năm 2019: Giảng viên, Trưởng Bộ môn Nội tổng hợp, Trường Đại học Y khoa Vinh."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "worked_as",
#       "object": "Giảng viên, Trưởng khoa Y học lâm sàng hệ Nội kiêm trưởng Bộ môn Nội tổng hợp, Trường Đại học Y khoa Vinh",
#       "metadata": {
#         "start_date": "0920-01-01T00:00:00Z",
#         "end_date": "0620-01-01T00:00:00Z",
#         "source": "Từ tháng 9 năm 2019 đến tháng 6 năm 2020: Giảng viên, Trưởng khoa Y học lâm sàng hệ Nội kiêm trưởng Bộ môn Nội tổng hợp, Trường Đại học Y khoa Vinh."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "worked_as",
#       "object": "Giảng viên, Phó Hiệu trưởng, kiêm Trưởng BM Nội tổng hợp, Trường Đại học Y khoa Vinh",
#       "metadata": {
#         "start_date": "0720-01-01T00:00:00Z",
#         "end_date": "0520-01-01T00:00:00Z",
#         "source": "Từ tháng 7 năm 2020 đến 5 năm 2023: Giảng viên, Phó Hiệu trưởng, kiêm Trưởng BM Nội tổng hợp, Trường Đại học Y khoa Vinh."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "worked_as",
#       "object": "Giảng viên, Hiệu trưởng, kiêm Trưởng BM Nội tổng hợp, Trường Đại học Y khoa Vinh",
#       "metadata": {
#         "start_date": "0620-01-01T00:00:00Z",
#         "end_date": "0120-01-01T00:00:00Z",
#         "source": "Từ tháng 6 năm 2023 đến nay: Giảng viên, Hiệu trưởng, kiêm Trưởng BM Nội tổng hợp, Trường Đại học Y khoa Vinh."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "position",
#       "object": "Hiệu trưởng, Trưởng BM Nội tổng hợp - Trường Đại học Y khoa Vinh",
#       "metadata": {
#         "source": "Chức vụ hiện nay: Hiệu trưởng, Trưởng BM Nội tổng hợp - Trường Đại học Y khoa Vinh."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "highest_position",
#       "object": "Hiệu trưởng - Trường Đại học Y khoa Vinh",
#       "metadata": {
#         "source": "Chức vụ cao nhất đã qua: Hiệu trưởng - Trường Đại học Y khoa Vinh."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "works_at",
#       "object": "Trường Đại học Y khoa Vinh",
#       "metadata": {
#         "source": "Cơ quan công tác hiện nay: Trường Đại học Y khoa Vinh"
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "address",
#       "object": "161 - Nguyễn Phong Sắc - Phường Hưng Dũng - Thành phố Vinh - Tỉnh Nghệ An",
#       "metadata": {
#         "source": "Địa chỉ cơ quan: 161 - Nguyễn Phong Sắc - Phường Hưng Dũng - Thành phố Vinh - Tỉnh Nghệ An."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "phone_number",
#       "object": "02383524062",
#       "metadata": {
#         "source": "Điện thoại cơ quan:\n02383524062"
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "teaching_at",
#       "object": "Trường Đại học Y dược Thái Bình",
#       "metadata": {
#         "source": "Thỉnh giảng tại các cơ sở giáo dục đại học: Trường Đại học Y dược Thái Bình"
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "degree",
#       "object": "Bác sĩ đa khoa",
#       "metadata": {
#         "start_date": "0819-01-01T00:00:00Z",
#         "end_date": "0819-01-01T00:00:00Z",
#         "source": "- Được cấp bằng ĐH ngày 25 tháng 8 năm 1998, ngành: Y , chuyên ngành: Bác\nsĩ đa khoa Nơi cấp bằng ĐH: Trường Đại học Y khoa Hà Nội - Việt Nam."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "awarded_by",
#       "object": "Trường Đại học Y khoa Hà Nội - Việt Nam",
#       "metadata": {
#         "start_date": "0819-01-01T00:00:00Z",
#         "end_date": "0819-01-01T00:00:00Z",
#         "source": "- Được cấp bằng ĐH ngày 25 tháng 8 năm 1998, ngành: Y , chuyên ngành: Bác\nsĩ đa khoa Nơi cấp bằng ĐH: Trường Đại học Y khoa Hà Nội - Việt Nam."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "degree",
#       "object": "Nội khoa",
#       "metadata": {
#         "start_date": "1220-01-01T00:00:00Z",
#         "end_date": "1220-01-01T00:00:00Z",
#         "source": "- Được cấp bằng Thạc sĩ ngày 18 tháng 12 năm 2003, ngành: Y; chuyên ngành: Nội khoa.\nNơi cấp bằng Thạc sĩ: Trường Đại học Y Dược Huế - Đại học Huế."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "awarded_by",
#       "object": "Trường Đại học Y Dược Huế - Đại học Huế",
#       "metadata": {
#         "start_date": "1220-01-01T00:00:00Z",
#         "end_date": "1220-01-01T00:00:00Z",
#         "source": "- Được cấp bằng Thạc sĩ ngày 18 tháng 12 năm 2003, ngành: Y; chuyên ngành: Nội khoa.\nNơi cấp bằng Thạc sĩ: Trường Đại học Y Dược Huế - Đại học Huế."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "degree",
#       "object": "Nội\nThận - Tiết niệu",
#       "metadata": {
#         "start_date": "1220-01-01T00:00:00Z",
#         "end_date": "1220-01-01T00:00:00Z",
#         "source": "- Được cấp bằng TS ngày 15 tháng 12 năm 2015, ngành: Y; chuyên ngành: Nội\nThận - Tiết niệu.\nNơi cấp bằng TS: Trường Đại học Y Dược Huế - Đại học Huế"
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "awarded_by",
#       "object": "Trường Đại học Y Dược Huế - Đại học Huế",
#       "metadata": {
#         "start_date": "1220-01-01T00:00:00Z",
#         "end_date": "1220-01-01T00:00:00Z",
#         "source": "- Được cấp bằng TS ngày 15 tháng 12 năm 2015, ngành: Y; chuyên ngành: Nội\nThận - Tiết niệu.\nNơi cấp bằng TS: Trường Đại học Y Dược Huế - Đại học Huế"
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "research_direction",
#       "object": "dịch tễ học các bệnh lý nội khoa",
#       "metadata": {
#         "source": "- Hướng nghiên cứu về dịch tễ học các bệnh lý nội khoa"
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "research_direction",
#       "object": "đặc điểm lâm sàng, cận lâm sàng, điều trị và theo dõi các\nbệnh lý nội khoa",
#       "metadata": {
#         "source": "- Hướng nghiên cứu về đặc điểm lâm sàng, cận lâm sàng, điều trị và theo dõi các\nbệnh lý nội khoa"
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "supervised",
#       "object": "02 học viên cao học bảo vệ thành công luận văn thạc sĩ",
#       "metadata": {
#         "source": "- Đã hướng dẫn chính 02 học viên cao học bảo vệ thành công luận văn thạc sĩ, 02\nhọc viên Bác sĩ CK2 bảo vệ thành công luận văn Bác sĩ chuyên khoa cấp II và hướng dẫn phụ 01 học viên cao học bảo vệ thành công luận văn thạc sĩ."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "supervised",
#       "object": "02 học viên Bác sĩ CK2 bảo vệ thành công luận văn Bác sĩ chuyên khoa cấp II",
#       "metadata": {
#         "source": "- Đã hướng dẫn chính 02 học viên cao học bảo vệ thành công luận văn thạc sĩ, 02\nhọc viên Bác sĩ CK2 bảo vệ thành công luận văn Bác sĩ chuyên khoa cấp II và hướng dẫn phụ 01 học viên cao học bảo vệ thành công luận văn thạc sĩ."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "supervised",
#       "object": "01 học viên cao học bảo vệ thành công luận văn thạc sĩ",
#       "metadata": {
#         "source": "- Đã hướng dẫn chính 02 học viên cao học bảo vệ thành công luận văn thạc sĩ, 02\nhọc viên Bác sĩ CK2 bảo vệ thành công luận văn Bác sĩ chuyên khoa cấp II và hướng dẫn phụ 01 học viên cao học bảo vệ thành công luận văn thạc sĩ."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "research_project",
#       "object": "01 đề tài nghiên cứu khoa học cấp tỉnh",
#       "metadata": {
#         "source": "- Đã chủ nhiệm 01 đề tài nghiên cứu khoa học cấp tỉnh, chủ nhiệm 06 đề tài khoa\nhọc cấp cơ sở, tham gia 01 đề tài khoa học cấp tỉnh và 03 đề tài nghiên cứu khoa học cấp cơ sở đã nghiệm thu."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "research_project",
#       "object": "06 đề tài khoa\nhọc cấp cơ sở",
#       "metadata": {
#         "source": "- Đã chủ nhiệm 01 đề tài nghiên cứu khoa học cấp tỉnh, chủ nhiệm 06 đề tài khoa\nhọc cấp cơ sở, tham gia 01 đề tài khoa học cấp tỉnh và 03 đề tài nghiên cứu khoa học cấp cơ sở đã nghiệm thu."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "research_project",
#       "object": "01 đề tài khoa học cấp tỉnh",
#       "metadata": {
#         "source": "- Đã chủ nhiệm 01 đề tài nghiên cứu khoa học cấp tỉnh, chủ nhiệm 06 đề tài khoa\nhọc cấp cơ sở, tham gia 01 đề tài khoa học cấp tỉnh và 03 đề tài nghiên cứu khoa học cấp cơ sở đã nghiệm thu."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "research_project",
#       "object": "03 đề tài nghiên cứu khoa học cấp cơ sở đã nghiệm thu",
#       "metadata": {
#         "source": "- Đã chủ nhiệm 01 đề tài nghiên cứu khoa học cấp tỉnh, chủ nhiệm 06 đề tài khoa\nhọc cấp cơ sở, tham gia 01 đề tài khoa học cấp tỉnh và 03 đề tài nghiên cứu khoa học cấp cơ sở đã nghiệm thu."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "published_articles",
#       "object": "85 bài báo khoa học",
#       "metadata": {
#         "source": "- Đã công bố 85 bài báo khoa học, trong đó có 03 bài báo khoa học công bố\ntrên tạp chí quốc tế có uy tín."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "published_articles",
#       "object": "03 bài báo khoa học công bố\ntrên tạp chí quốc tế có uy tín",
#       "metadata": {
#         "source": "- Đã công bố 85 bài báo khoa học, trong đó có 03 bài báo khoa học công bố\ntrên tạp chí quốc tế có uy tín."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "books_published",
#       "object": "03",
#       "metadata": {
#         "source": "- Số lượng sách đã xuất bản 03, trong đó 03 sách thuộc nhà xuất bản có uy tín;"
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "award",
#       "object": "Bằng khen của Thủ tướng Chính phủ",
#       "metadata": {
#         "start_date": "0120-01-01T00:00:00Z",
#         "end_date": "0120-01-01T00:00:00Z",
#         "source": "- Bằng khen của Thủ tướng Chính phủ năm 2020 (Quyết định số 97/QĐ-TTg ngày\n16/01/2020 của Thủ tướng Chính phủ)."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "award",
#       "object": "Bằng khen của Bộ trưởng Bộ Giáo dục và Đào tạo",
#       "metadata": {
#         "start_date": "0920-01-01T00:00:00Z",
#         "end_date": "0920-01-01T00:00:00Z",
#         "source": "- Bằng khen của Bộ trưởng Bộ Giáo dục và Đào tạo năm 2020 (Quyết định số\n2681/QĐ-BGDĐT ngày 18/9/2020 của Bộ trưởng Bộ Giáo dục và Đào tạo)."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "award",
#       "object": "danh hiệu chiến sĩ thi đua cấp tỉnh",
#       "metadata": {
#         "start_date": "0120-01-01T00:00:00Z",
#         "end_date": "0120-01-01T00:00:00Z",
#         "source": "- Danh hiệu chiến sĩ thi đua cấp tỉnh năm 2018 (Quyết định số 4370/QĐ-UBND\nngày 01/10/2018 của Chủ tịch UBND tỉnh Nghệ An)."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "award",
#       "object": "Kỷ niệm chương “Vì thế hệ trẻ”",
#       "metadata": {
#         "start_date": "0920-01-01T00:00:00Z",
#         "end_date": "0920-01-01T00:00:00Z",
#         "source": "- Kỷ niệm chương “Vì thế hệ trẻ” về thành tích đóng góp vào sự nghiệp giáo dục\nthế hệ trẻ và xây dựng tổ chức Đoàn (Quyết định số 259/QĐ/TWĐTN ngày 15/9/2020 của Ban chấp hành Trung ương Đoàn TNCS Hồ Chí Minh)."
#       }
#     },
#     {
#       "subject": "NGUYỄN VĂN TUẤN",
#       "predicate": "award",
#       "object": "Bằng khen của Chủ tịch UBND tỉnh Nghệ An",
#       "metadata": {
#         "start_date": "0820-01-01T00:00:00Z",
#         "end_date": "0820-01-01T00:00:00Z",
#         "source": "- Bằng khen của Chủ tịch UBND tỉnh Nghệ An vì đã có thành tích tiêu biểu trong\nlĩnh vực Khoa học và Công Nghệ, góp phần vào sự nghiệp phát triển Kinh tế - Xã hội trên địa bàn tỉnh Nghệ An (Quyết định số 2569/QĐ-UBND ngày 21 tháng 8 năm 2023 của Chủ tịch UBND tỉnh Nghệ An)."
#       }
#     }
#   ]
# }
# {
#   "triples": [
#     {
#       "subject": "Nguyễn Thị Khánh Vân",
#       "predicate": "has_birth_date",
#       "object": "02-09-1969",
#       "metadata": {
#         "source": "2. Ngày tháng năm sinh: 02/09/1969; Nam \nf0a3; Nữ \nf052 ; Quốc tịch: Việt Nam;"
#       }
#     },
#     {
#       "subject": "Nguyễn Thị Khánh Vân",
#       "predicate": "gender",
#       "object": "Nữ",
#       "metadata": {
#         "source": "2. Ngày tháng năm sinh: 02/09/1969; Nam \nf0a3; Nữ \nf052 ; Quốc tịch: Việt Nam;"
#       }
#     },
#     {
#       "subject": "Nguyễn Thị Khánh Vân",
#       "predicate": "nationality",
#       "object": "Việt Nam",
#       "metadata": {
#         "source": "2. Ngày tháng năm sinh: 02/09/1969; Nam \nf0a3; Nữ \nf052 ; Quốc tịch: Việt Nam;"
#       }
#     },
#     {
#       "subject": "Nguyễn Thị Khánh Vân",
#       "predicate": "ethnicity",
#       "object": "Kinh",
#       "metadata": {
#         "source": "Dân tộc: Kinh; Tôn giáo: Không"
#       }
#     },
#     {
#       "subject": "Nguyễn Thị Khánh Vân",
#       "predicate": "religion",
#       "object": "Không",
#       "metadata": {
#         "source": "Dân tộc: Kinh; Tôn giáo: Không"
#       }
#     },
#     {
# ...
#             "predicate": "received_degree",
#             "object": "Đại học Tự do, Vương quốc Bỉ (Y tế Công cộng, chuyên ngành: Phương pháp Y tế Công cộng)",
#             "metadata": {
#                 "start_date": "0620-07-28T00:00:00+07:00",
#                 "source": "➢ Được cấp bằng ThS ngày 28 tháng 06 năm 2007 số văn bằng: ………..; ngành: Y tế Công cộng; chuyên ngành: Phương pháp Y tế Công cộng; Nơi cấp bằng ThS: Đại học Tự do, Vương quốc Bỉ."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "received_degree",
#             "object": "Đại học Basel, Thụy Sỹ (Dịch tễ học)",
#             "metadata": {
#                 "start_date": "1220-12-13T00:00:00+07:00",
#                 "source": "➢ Được cấp bằng TS ngày 13 tháng 12 năm 2017; số văn bằng: ………..; ngành:Dịch tễ học; Nơi cấp bằng TS: Đại học Basel, Thụy Sỹ."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "research_direction",
#             "object": "Gánh nặng bệnh tật và các yếu tố nguy cơ",
#             "metadata": {
#                 "source": "✓ Gánh nặng bệnh tật và các yếu tố nguy cơ."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "research_direction",
#             "object": "Tác động sức khỏe của ô nhiễm không khí bên ngoài và thời tiết cực đoan",
#             "metadata": {
#                 "source": "✓ Tác động sức khỏe của ô nhiễm không khí bên ngoài và thời tiết cực đoan"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "research_direction",
#             "object": "Đánh giá chất lượng dịch vụ y tế",
#             "metadata": {
#                 "source": "✓ Đánh giá chất lượng dịch vụ y tế"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "supervised",
#             "object": "23 HVCH/CK2",
#             "metadata": {
#                 "source": "- Đã hướng dẫn 23 HVCH/CK2 bảo vệ thành công luận văn ThS/CK2."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "completed_research",
#             "object": "02 đề tài NCKH cấp cơ sở",
#             "metadata": {
#                 "source": "- Đã hoàn thành: 02 đề tài NCKH cấp cơ sở; 01 cấp nhà nước (NAFOSTED);"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "completed_research",
#             "object": "01 cấp nhà nước (NAFOSTED)",
#             "metadata": {
#                 "source": "- Đã hoàn thành: 02 đề tài NCKH cấp cơ sở; 01 cấp nhà nước (NAFOSTED);"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "published_papers",
#             "object": "56 bài báo khoa học",
#             "metadata": {
#                 "source": "- Đã công bố: 56 bài báo khoa học, trong đó 16 bài báo khoa học trên tạp chí quốc tế có uy\ntín (ISI)."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "published_papers",
#             "object": "16 bài báo khoa học trên tạp chí quốc tế có uy tín (ISI)",
#             "metadata": {
#                 "source": "- Đã công bố: 56 bài báo khoa học, trong đó 16 bài báo khoa học trên tạp chí quốc tế có uy\ntín (ISI)."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "published_as_main_author",
#             "object": "9/16 bài",
#             "metadata": {
#                 "source": "Trong đó có 9/16 bài là tác giả chính (07 bài có chỉ số IF>2)."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "published_as_main_author",
#             "object": "07 bài",
#             "metadata": {
#                 "source": "Trong đó có 9/16 bài là tác giả chính (07 bài có chỉ số IF>2)."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "published_papers_after_phd",
#             "object": "12",
#             "metadata": {
#                 "source": "Số bài báo khoa học trên tạp chí quốc tế có uy tín sau Tiến sỹ là 12, trong đó có 6 bài là tác giả chính."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "published_as_main_author_after_phd",
#             "object": "6 bài",
#             "metadata": {
#                 "source": "Số bài báo khoa học trên tạp chí quốc tế có uy tín sau Tiến sỹ là 12, trong đó có 6 bài là tác giả chính."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "awarded",
#             "object": "00 bằng độc quyền sáng chế, giải pháp hữu ích",
#             "metadata": {
#                 "source": "- Đã được cấp 00 bằng độc quyền sáng chế, giải pháp hữu ích;"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "published_books",
#             "object": "03",
#             "metadata": {
#                 "source": "- Số lượng sách đã xuất bản 03 trong đó 03 thuộc nhà xuất bản có uy tín;"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Lao động tiên tiến",
#             "metadata": {
#                 "start_date": "2017-01-01T00:00:00+07:00",
#                 "end_date": "2018-01-01T00:00:00+07:00",
#                 "source": "2017 - 2018 Lao động tiên tiến Quyết định số 2735/QĐ-ĐHYTCC ngày 30/11/2018 của Hiệu trưởng Trường Đại học Y tế công cộng"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Lao động tiên tiến",
#             "metadata": {
#                 "start_date": "2018-01-01T00:00:00+07:00",
#                 "end_date": "2019-01-01T00:00:00+07:00",
#                 "source": "2018 - 2019 Lao động tiên tiến Quyết định số 1170/QĐ-ĐHYTCC ngày 03/10/2019 của Hiệu trưởng Trường Đại học Y tế công cộng"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Lao động tiên tiến",
#             "metadata": {
#                 "start_date": "2019-01-01T00:00:00+07:00",
#                 "end_date": "2020-01-01T00:00:00+07:00",
#                 "source": "2019 - 2020 Lao động tiên tiến Quyết định số 828/QĐ-ĐHYTCC ngày 30/9/2020 của Hiệu trưởng Trường Đại học Y tế công cộng"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Lao động tiên tiến",
#             "metadata": {
#                 "start_date": "2020-01-01T00:00:00+07:00",
#                 "end_date": "2021-01-01T00:00:00+07:00",
#                 "source": "2020 - 2021 Lao động tiên tiến Quyết định số 740/QĐ-ĐHYTCC ngày 11/10/2021 của Hiệu trưởng Trường Đại học Y tế công cộng"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Lao động tiên tiến",
#             "metadata": {
#                 "start_date": "2021-01-01T00:00:00+07:00",
#                 "end_date": "2022-01-01T00:00:00+07:00",
#                 "source": "2021 - 2022 Lao động tiên tiến Quyết định số 1180/QĐ-ĐHYTCC ngày 12/10/2022 của Hiệu trưởng Trường Đại học Y tế công cộng"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Lao động tiên tiến",
#             "metadata": {
#                 "start_date": "2022-01-01T00:00:00+07:00",
#                 "end_date": "2023-01-01T00:00:00+07:00",
#                 "source": "2022 - 2023 Lao động tiên tiến Quyết định số 666/QĐ-ĐHYTCC ngày 12/10/2023 của Hiệu trưởng Trường Đại học Y tế công cộng"
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Bằng khen Bộ trưởng Bộ Y tế",
#             "metadata": {
#                 "start_date": "2021-02-17T00:00:00+07:00",
#                 "source": "- Bằng khen Bộ trưởng Bộ Y tế do có thành tích, đóng góp trong quá trình xây dựng và\nphát triển Nhà trường (Quyết định số 1310/QĐ-BYT ngày 17/02/2021 của Bộ trưởng Bộ Y tế)."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Giấy khen Hiệu trưởng",
#             "metadata": {
#                 "start_date": "2016-01-01T00:00:00+07:00",
#                 "end_date": "2017-01-01T00:00:00+07:00",
#                 "source": "- Giấy khen Hiệu trưởng năm học 2016 - 2017 (Quyết định số 1953/QĐ-ĐHYTCC ngày\n30/11/2017 của Hiệu trưởng Trường Đại học Y tế công cộng) và năm học 2017 - 2018 (Quyết định số 2735/QĐ-ĐHYTCC ngày 30/11/2018 của Hiệu trưởng Trường Đại học Y tế công cộng)."
#             }
#         },
#         {
#             "subject": "NGUYỄN THỊ TRANG NHUNG",
#             "predicate": "award",
#             "object": "Giấy khen Hiệu trưởng",
#             "metadata": {
#                 "start_date": "2017-01-01T00:00:00+07:00",
#                 "end_date": "2018-01-01T00:00:00+07:00",
#                 "source": "- Giấy khen Hiệu trưởng năm học 2016 - 2017 (Quyết định số 1953/QĐ-ĐHYTCC ngày\n30/11/2017 của Hiệu trưởng Trường Đại học Y tế công cộng) và năm học 2017 - 2018 (Quyết định số 2735/QĐ-ĐHYTCC ngày 30/11/2018 của Hiệu trưởng Trường Đại học Y tế công cộng)."
#             }
#         }
#     ]
# }
# ERROR:root:Message: Unterminated string starting at: line 16 column 19 (char 347)
# Traceback (most recent call last):
#   File "/Users/huynhnguyen/WorkDir/bachoc_1/src/KG_builder/extract/extract_triples.py", line 16, in extract_triples
#     res = json.loads(response)
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/json/decoder.py", line 345, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#                ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/json/decoder.py", line 361, in raw_decode
#     obj, end = self.scan_once(s, idx)
#                ~~~~~~~~~~~~~~^^^^^^^^
# json.decoder.JSONDecodeError: Unterminated string starting at: line 16 column 19 (char 347)
# {
#   "triples": [
#     {
#       "subject": "ĐỖ VĂN CHIẾN",
#       "predicate": "has_birth_date",
#       "object": "17-11-1980",
#       "metadata": {
#         "source": "Ngày tháng năm sinh: 17 - 11 - 1980"
#       }
#     },
#     {
#       "subject": "ĐỖ VĂN CHIẾN",
#       "predicate": "has_gender",
#       "object": "Nam",
#       "metadata": {
#         "source": "Ngày tháng năm sinh: 17 - 11 - 1980; \n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t ...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[17], line 36
#      29     context_kwargs["main_subject"] = main_subject
#      31 messages = {
#      32     "system_instruction": system_instruction.format(),
#      33     "context": context.format(**context_kwargs)
#      34 }
# ---> 36 response = extract_triples(
#      37     messages=messages,
#      38     llm=llm,
#      39     response_format=response_format
#      40 )
#      42 for triple in response["triples"]:
#      43     if not isinstance(triple, dict):
#
# File ~/WorkDir/bachoc_1/src/KG_builder/extract/extract_triples.py:20, in extract_triples(messages, llm, **args)
#      17 except Exception as e:
#      18     logging.exception(f"Message: {e}")
# ---> 20 return res
#
# UnboundLocalError: cannot access local variable 'res' where it is not associated with a value

# %%
len(triples)
# Out:
# 47
